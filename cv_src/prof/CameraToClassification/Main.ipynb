# %% [markdown]
# Main Code

# %%
import CameraGUI as cam
import yolotest as yolo
import ModelTraining as mt
while(True):
    images= yolo.runyolo(yolocam.read_camera_image(cam.start_camera()))
    for image in images:

        mt.predict_image("CameraToClassification\Models\trained_model_masked_colour.h5",)
